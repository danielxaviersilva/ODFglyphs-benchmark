# %%
from matplotlib import pyplot as plt
import numpy as np
import csv
import math
import pandas as pd
import seaborn as sns

# %%
dataNotInstanced42 = pd.read_csv('Standard_V42.txt', delimiter = ',', header = None)
avgDataNotInstanced42 = dataNotInstanced42.groupby([0], as_index = False).mean()#.reset_index()
avgDataNotInstanced42[1] = 1e6/avgDataNotInstanced42[1]

dataNotInstanced162 = pd.read_csv('Standard_V162.txt', delimiter = ',', header = None)
avgDataNotInstanced162 = dataNotInstanced162.groupby([0], as_index = False).mean()#.reset_index()
avgDataNotInstanced162[1] = 1e6/avgDataNotInstanced162[1]


dataNotInstanced642 = pd.read_csv('Standard_V642.txt', delimiter = ',', header = None)
avgDataNotInstanced642 = dataNotInstanced642.groupby([0], as_index = False).mean()#.reset_index()
avgDataNotInstanced642[1] = 1e6/avgDataNotInstanced642[1]

dataNotInstanced2562 = pd.read_csv('Standard_V2562.txt', delimiter = ',', header = None)
avgDataNotInstanced2562 = dataNotInstanced2562.groupby([0], as_index = False).mean()#.reset_index()
avgDataNotInstanced2562[1] = 1e6/avgDataNotInstanced2562[1]

dataNotInstanced42 = pd.read_csv('Standard_V42.txt', delimiter = ',', header = None)
avgDataNotInstanced42 = dataNotInstanced42.groupby([0], as_index = False).mean()#.reset_index()
avgDataNotInstanced42[1] = 1e6/avgDataNotInstanced42[1]

dataNotInstanced162 = pd.read_csv('Standard_V162.txt', delimiter = ',', header = None)
avgDataNotInstanced162 = dataNotInstanced162.groupby([0], as_index = False).mean()#.reset_index()
avgDataNotInstanced162[1] = 1e6/avgDataNotInstanced162[1]


dataNotInstanced642 = pd.read_csv('Standard_V642.txt', delimiter = ',', header = None)
avgDataNotInstanced642 = dataNotInstanced642.groupby([0], as_index = False).mean()#.reset_index()
avgDataNotInstanced642[1] = 1e6/avgDataNotInstanced642[1]

dataNotInstanced2562 = pd.read_csv('Standard_V2562.txt', delimiter = ',', header = None)
avgDataNotInstanced2562 = dataNotInstanced2562.groupby([0], as_index = False).mean()#.reset_index()
avgDataNotInstanced2562[1] = 1e6/avgDataNotInstanced2562[1]


fig , ax = plt.subplots()
#ax.plot(avgDataNotInstanced162[0],  np.repeat(60,avgDataNotInstanced162[0].shape), label ='60Hz mark')

ax.set_xlabel('Quantidade de glifos')  # Add an x-label to the axes.
ax.set_ylabel('FPS')  # Add a y-label to the axes.

ax.plot(avgDataNotInstanced42[0], avgDataNotInstanced42[1], label='2ª ordem')
ax.plot(avgDataNotInstanced162[0], avgDataNotInstanced162[1], label='4ª ordem')
ax.plot(avgDataNotInstanced642[0], avgDataNotInstanced642[1], label='8ª ordem')
ax.plot(avgDataNotInstanced2562[0], avgDataNotInstanced2562[1], label='16ª ordem')

ax.set_xlim(left=0);
ax.set_ylim(bottom=0);
ax.set_xticks([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000]);
ax.legend();

# %%
dataFull42 = pd.read_csv('Instanced_V42.txt', delimiter = ',', header = None)
avgDataFull42 = dataFull42.groupby([0], as_index = False).mean()#.reset_index()
avgDataFull42[1] = 1e6/avgDataFull42[1]

dataFull162 = pd.read_csv('Instanced_V162.txt', delimiter = ',', header = None)
avgDataFull162 = dataFull162.groupby([0], as_index = False).mean()#.reset_index()
avgDataFull162[1] = 1e6/avgDataFull162[1]


dataFull642 = pd.read_csv('Instanced_V642.txt', delimiter = ',', header = None)
avgDataFull642 = dataFull642.groupby([0], as_index = False).mean()#.reset_index()
avgDataFull642[1] = 1e6/avgDataFull642[1]

dataFull2562 = pd.read_csv('Instanced_V2562.txt', delimiter = ',', header = None)
avgDataFull2562 = dataFull2562.groupby([0], as_index = False).mean()#.reset_index()
avgDataFull2562[1] = 1e6/avgDataFull2562[1]

# %%
fig , ax = plt.subplots()
#ax.plot(avgDataFull162[0],  np.repeat(60,avgDataFull162[0].shape), label ='60Hz mark')

ax.set_xlabel('Quantidade de glifos')  # Add an x-label to the axes.
ax.set_ylabel('FPS')  # Add a y-label to the axes.

ax.plot(avgDataNotInstanced2562[0], avgDataNotInstanced2562[1], 'k--', label='Primeira série')
ax.plot(avgDataFull2562[0],         avgDataFull2562[1], label='Segunda série')
ax.set_xlim(left=0)
ax.set_ylim(bottom=0)
ax.set_xticks([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
ax.legend();

# %%
fig , ax = plt.subplots()
#ax.plot(avgDataFull162[0],  np.repeat(60,avgDataFull162[0].shape), label ='60Hz mark')

ax.set_xlabel('Quantidade de glifos')  # Add an x-label to the axes.
ax.set_ylabel('FPS')  # Add a y-label to the axes.

ax.plot(avgDataNotInstanced642[0], avgDataNotInstanced642[1], 'k--', label='Primeira série')
ax.plot(avgDataFull642[0],         avgDataFull642[1], label='Segunda série')
ax.set_xlim(left=0)
ax.set_ylim(bottom=0)
ax.set_xticks([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
ax.legend()

# %%
fig , ax = plt.subplots()
#ax.plot(avgDataFull162[0],  np.repeat(60,avgDataFull162[0].shape), label ='60Hz mark')

ax.set_xlabel('Quantidade de glifos')  # Add an x-label to the axes.
ax.set_ylabel('FPS')  # Add a y-label to the axes.

ax.plot(avgDataNotInstanced162[0], avgDataNotInstanced162[1], 'k--', label='Primeira série')
ax.plot(avgDataFull162[0],         avgDataFull162[1], label='Segunda série')
ax.set_xlim(left=0)
ax.set_ylim(bottom=0)
ax.set_xticks([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
ax.legend()

# %%
fig , ax = plt.subplots()
#ax.plot(avgDataFull162[0],  np.repeat(60,avgDataFull162[0].shape), label ='60Hz mark')

ax.set_xlabel('Quantidade de glifos')  # Add an x-label to the axes.
ax.set_ylabel('FPS')  # Add a y-label to the axes.

ax.plot(avgDataNotInstanced42[0], avgDataNotInstanced42[1], 'k--', label='Primeira série')
ax.plot(avgDataFull42[0],         avgDataFull42[1], label='Segunda série')
ax.set_xlim(left=0)
ax.set_ylim(bottom=0)
ax.set_xticks([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
ax.legend()

# %%
dataHalf42 = pd.read_csv('InstancedSymmetric_V42.txt', delimiter = ',', header = None)
avgDataHalf42 = dataHalf42.groupby([0], as_index = False).mean()#.reset_index()
avgDataHalf42[1] = 1e6/avgDataHalf42[1]

dataHalf162 = pd.read_csv('InstancedSymmetric_V162.txt', delimiter = ',', header = None)
avgDataHalf162 = dataHalf162.groupby([0], as_index = False).mean()#.reset_index()
avgDataHalf162[1] = 1e6/avgDataHalf162[1]


dataHalf642 = pd.read_csv('InstancedSymmetric_V642.txt', delimiter = ',', header = None)
avgDataHalf642 = dataHalf642.groupby([0], as_index = False).mean()#.reset_index()
avgDataHalf642[1] = 1e6/avgDataHalf642[1]

dataHalf2562 = pd.read_csv('InstancedSymmetric_V2562.txt', delimiter = ',', header = None)
avgDataHalf2562 = dataHalf2562.groupby([0], as_index = False).mean()#.reset_index()
avgDataHalf2562[1] = 1e6/avgDataHalf2562[1]

# %%
fig , ax = plt.subplots()
#ax.plot(avgDataFull162[0],  np.repeat(60,avgDataFull162[0].shape), label ='60Hz mark')

ax.set_xlabel('Quantidade de glifos')  # Add an x-label to the axes.
ax.set_ylabel('FPS')  # Add a y-label to the axes.

ax.plot(avgDataFull2562[0], avgDataFull2562[1], 'k--', color='blue', label='Segunda série')
ax.plot(avgDataHalf2562[0], avgDataHalf2562[1], color = 'red', label='Terceira série')

ax.set_xlim(left=0)
ax.set_ylim(bottom=0)
ax.set_xticks([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
ax.legend()

# %%
fig , ax = plt.subplots()
#ax.plot(avgDataFull162[0],  np.repeat(60,avgDataFull162[0].shape), label ='60Hz mark')

ax.set_xlabel('Quantidade de glifos')  # Add an x-label to the axes.
ax.set_ylabel('FPS')  # Add a y-label to the axes.

ax.plot(avgDataFull642[0], avgDataFull642[1], 'k--', color='blue', label='Segunda série')
ax.plot(avgDataHalf642[0], avgDataHalf642[1], color = 'red', label='Terceira série')

ax.set_xlim(left=0)
ax.set_ylim(bottom=0)
ax.set_xticks([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
ax.legend()

# %%
fig , ax = plt.subplots()
#ax.plot(avgDataFull162[0],  np.repeat(60,avgDataFull162[0].shape), label ='60Hz mark')

ax.set_xlabel('Quantidade de glifos')  # Add an x-label to the axes.
ax.set_ylabel('FPS')  # Add a y-label to the axes.

ax.plot(avgDataFull162[0], avgDataFull162[1], 'k--', color='blue', label='Segunda série')
ax.plot(avgDataHalf162[0], avgDataHalf162[1], color = 'red', label='Terceira série')

ax.set_xlim(left=0)
ax.set_ylim(bottom=0)
ax.set_xticks([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
ax.legend()

# %%
fig , ax = plt.subplots()
#ax.plot(avgDataFull162[0],  np.repeat(60,avgDataFull162[0].shape), label ='60Hz mark')

ax.set_xlabel('Quantidade de glifos')  # Add an x-label to the axes.
ax.set_ylabel('FPS')  # Add a y-label to the axes.

ax.plot(avgDataFull42[0], avgDataFull42[1], 'k--', color='blue', label='Segunda série')
ax.plot(avgDataHalf42[0], avgDataHalf42[1], color = 'red', label='Terceira série')

ax.set_xlim(left=0)
ax.set_ylim(bottom=0)
ax.set_xticks([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
ax.legend()

# %%
dataOptTexHalf42 = pd.read_csv('InstancedSymmetricCoalescent_V42.txt', delimiter = ',', header = None)
avgDataOptTexHalf42 = dataOptTexHalf42.groupby([0], as_index = False).mean()#.reset_index()
avgDataOptTexHalf42[1] = 1e6/avgDataOptTexHalf42[1]

dataOptTexHalf162 = pd.read_csv('InstancedSymmetricCoalescent_V162.txt', delimiter = ',', header = None)
avgDataOptTexHalf162 = dataOptTexHalf162.groupby([0], as_index = False).mean()#.reset_index()
avgDataOptTexHalf162[1] = 1e6/avgDataOptTexHalf162[1]


dataOptTexHalf642 = pd.read_csv('InstancedSymmetricCoalescent_V642.txt', delimiter = ',', header = None)
avgDataOptTexHalf642 = dataOptTexHalf642.groupby([0], as_index = False).mean()#.reset_index()
avgDataOptTexHalf642[1] = 1e6/avgDataOptTexHalf642[1]

dataOptTexHalf2562 = pd.read_csv('InstancedSymmetricCoalescent_V2562.txt', delimiter = ',', header = None)
avgDataOptTexHalf2562 = dataOptTexHalf2562.groupby([0], as_index = False).mean()#.reset_index()
avgDataOptTexHalf2562[1] = 1e6/avgDataOptTexHalf2562[1]

# %%
fig , ax = plt.subplots()
#ax.plot(avgDataFull162[0],  np.repeat(60,avgDataFull162[0].shape), label ='60Hz mark')

ax.set_xlabel('Quantidade de glifos')  # Add an x-label to the axes.
ax.set_ylabel('FPS')  # Add a y-label to the axes.

ax.plot(avgDataHalf2562[0], avgDataHalf2562[1], 'k--', color = 'red', label='Terceira série')
ax.plot(avgDataOptTexHalf2562[0], avgDataOptTexHalf2562[1], color='magenta', label='Quarta série')

ax.set_xlim(left=0)
ax.set_ylim(bottom=0)
ax.set_xticks([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
ax.legend()

# %%
fig , ax = plt.subplots()
#ax.plot(avgDataFull162[0],  np.repeat(60,avgDataFull162[0].shape), label ='60Hz mark')

ax.set_xlabel('Quantidade de glifos')  # Add an x-label to the axes.
ax.set_ylabel('FPS')  # Add a y-label to the axes.

ax.plot(avgDataHalf642[0], avgDataHalf642[1], 'k--', color = 'red', label='Terceira série')
ax.plot(avgDataOptTexHalf642[0], avgDataOptTexHalf642[1], color='magenta', label='Quarta série')

ax.set_xlim(left=0)
ax.set_ylim(bottom=0)
ax.set_xticks([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
ax.legend()

# %%
fig , ax = plt.subplots()
#ax.plot(avgDataFull162[0],  np.repeat(60,avgDataFull162[0].shape), label ='60Hz mark')

ax.set_xlabel('Quantidade de glifos')  # Add an x-label to the axes.
ax.set_ylabel('FPS')  # Add a y-label to the axes.

ax.plot(avgDataHalf162[0], avgDataHalf162[1], 'k--', color = 'red', label='Terceira série')
ax.plot(avgDataOptTexHalf162[0], avgDataOptTexHalf162[1], color='magenta', label='Quarta série')

ax.set_xlim(left=0)
ax.set_ylim(bottom=0)
ax.set_xticks([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
ax.legend()

# %%
fig , ax = plt.subplots()
#ax.plot(avgDataFull162[0],  np.repeat(60,avgDataFull162[0].shape), label ='60Hz mark')

ax.set_xlabel('Quantidade de glifos')  # Add an x-label to the axes.
ax.set_ylabel('FPS')  # Add a y-label to the axes.

ax.plot(avgDataHalf42[0], avgDataHalf42[1], 'k--', color = 'red', label='Terceira série')
ax.plot(avgDataOptTexHalf42[0], avgDataOptTexHalf42[1], color='magenta', label='Quarta série')

ax.set_xlim(left=0)
ax.set_ylim(bottom=0)
ax.set_xticks([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
ax.legend()
